# %%
from jarvismarch import jarvismarch
import matplotlib.pyplot as plt

import random

class Point:
    def __init__(self,x,y):
        self.x = x
        self.y = y
        
def generateRandomPoints(n):
    myPoints = []

    for i in range(n):
        myPoints.append(Point(random.randint(1, 100), random.randint(1, 100)))

    return myPoints
        

def scatterPlotPoints(points):
    xPoints = [point.x for point in points]
    yPoints = [point.y for point in points]

    for point in points:
        plt.scatter(point.x, point.y)

def plotConvexHull(points):
    xPoints = [point.x for point in points]
    yPoints = [point.y for point in points]

    xPoints.append(xPoints[0])
    yPoints.append(yPoints[0])

    plt.plot(xPoints, yPoints)
    
inputSet = generateRandomPoints(50)
outputSet = jarvismarch(inputSet)

print(outputSet)
scatterPlotPoints(inputSet)
plotConvexHull(outputSet)

plt.show()
# Out:
# [<__main__.Point object at 0x1120ad880>, <__main__.Point object at 0x111fcb260>, <__main__.Point object at 0x1119c6180>, <__main__.Point object at 0x111cc77a0>, <__main__.Point object at 0x111b86840>, <__main__.Point object at 0x111f04ec0>, <__main__.Point object at 0x111f04710>, <__main__.Point object at 0x111e74530>, <__main__.Point object at 0x111e751f0>, <__main__.Point object at 0x111e77f20>, <__main__.Point object at 0x111e77890>, <__main__.Point object at 0x111e74bf0>, <__main__.Point object at 0x111e764b0>, <__main__.Point object at 0x111e75910>, <__main__.Point object at 0x111b2df70>, <__main__.Point object at 0x111b2d730>, <__main__.Point object at 0x111b2fb00>, <__main__.Point object at 0x111b2e4e0>, <__main__.Point object at 0x111a9d580>, <__main__.Point object at 0x111a9d9d0>, <__main__.Point object at 0x111a9dc40>, <__main__.Point object at 0x111993020>, <__main__.Point object at 0x1119929c0>, <__main__.Point object at 0x111d871a0>, <__main__.Point object at 0x111d87380>, <__main__.Point object at 0x111d85af0>, <__main__.Point object at 0x111d84140>, <__main__.Point object at 0x111df6c00>, <__main__.Point object at 0x112055a30>, <__main__.Point object at 0x112057fe0>, <__main__.Point object at 0x112055520>, <__main__.Point object at 0x112057a10>, <__main__.Point object at 0x1120558e0>, <__main__.Point object at 0x112057ec0>, <__main__.Point object at 0x1120550d0>, <__main__.Point object at 0x112055a00>, <__main__.Point object at 0x1120573b0>, <__main__.Point object at 0x112054260>, <__main__.Point object at 0x1120543b0>, <__main__.Point object at 0x112057290>, <__main__.Point object at 0x1120572c0>, <__main__.Point object at 0x1120568a0>, <__main__.Point object at 0x1120affb0>, <__main__.Point object at 0x1120ad6d0>, <__main__.Point object at 0x1120ae270>, <__main__.Point object at 0x1120ae3f0>, <__main__.Point object at 0x1120ae780>, <__main__.Point object at 0x1120add60>, <__main__.Point object at 0x1120ac740>, <__main__.Point object at 0x1120add00>]
